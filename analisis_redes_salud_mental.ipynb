# %% [markdown]
# <a href="https://colab.research.google.com/github/Mera-15/impacto_redes_salud_mental/blob/main/analisis_redes_salud_mental.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Análisis: Impacto de las Redes Sociales en la Salud Mental Adolescente
#
# ## 1. Planteamiento del Problema e Hipótesis
# El objetivo de este proyecto es analizar la relación entre el uso de redes sociales y los indicadores de salud mental en adolescentes.
#
# **Hipótesis a evaluar:**
# 1. Existe una correlación positiva entre la cantidad de horas diarias en redes sociales y el puntaje de depresión.
# 2. Ante niveles similares de uso, las mujeres presentan puntajes promedio de depresión más altos que los hombres.
# 3. Existe una relación inversamente proporcional entre la frecuencia de ejercicio físico y el tiempo de uso de redes sociales.

# %%
import pandas as pd
import plotly.express as px

df = pd.read_csv('Teen_Mental_Health_Dataset.csv')
# Out:
#    age  gender  daily_social_media_hours platform_usage  sleep_hours  \
# 0   14    male                       7.9      Instagram          7.4
# 1   19  female                       1.9         TikTok          8.0
# 2   17  female                       1.3      Instagram          7.6
# 3   15    male                       7.4         TikTok          6.9
# 4   15  female                       4.7           Both          4.9
#
#    screen_time_before_sleep  academic_performance  physical_activity  \
# 0                       2.9                  3.01                1.5
# 1                       2.9                  3.22                0.8
# 2                       0.5                  3.92                0.0
# 3                       1.6                  3.48                0.8
# 4                       3.0                  2.37                1.4
#
#   social_interaction_level  stress_level  anxiety_level  addiction_level  \
# ...
